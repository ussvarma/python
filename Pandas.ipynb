# %%
import pandas as pd
import numpy as np
data={'name':['harish','varma','dheeraj'],"age":[21,20,19]}
df=pd.DataFrame(data)
print(df)
# Out:
#       name  age
# 0   harish   21
# 1    varma   20
# 2  dheeraj   19

# %%
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
df1=pd.DataFrame(data1)
print(df1[['Name', 'Qualification']]) #accessing required columns of a dataframe
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
data=pd.read_csv("/home/neosoft/Downloads/nba.csv", index_col="Name")
print(data)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
first = data.loc["Avery Bradley"] #retrieving row using loc method
print("row of name containing Avery Bradley:",first)
print(data.columns) #printing name of columns
# Out:
# row of name containing Avery Bradley: Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'],
#       dtype='object')

# %%
# retrieving rows by iloc method 
row2 = data.iloc[0] 
print(row2)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
#how to findout missing data
# retrieving rows by iloc method 
row2 = data.isnull()
print(row2)
# Out:
#                 Team  Number  Position    Age  Height  Weight  College  Salary
# Name
# Avery Bradley  False   False     False  False   False   False    False   False
# Jae Crowder    False   False     False  False   False   False    False   False
# John Holland   False   False     False  False   False   False    False    True
# R.J. Hunter    False   False     False  False   False   False    False   False
# Jonas Jerebko  False   False     False  False   False   False     True   False
# ...              ...     ...       ...    ...     ...     ...      ...     ...
# Shelvin Mack   False   False     False  False   False   False    False   False
# Raul Neto      False   False     False  False   False   False     True   False
# Tibor Pleiss   False   False     False  False   False   False     True   False
# Jeff Withey    False   False     False  False   False   False    False   False
# NaN             True    True      True   True    True    True     True    True
#
# ...

# %%
print(data.fillna(0))
data
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                         0     0.0        0   0.0      0     0.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
#now dropping row with nan values here with 0
print(data.dropna())
data
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# ...                       ...     ...      ...   ...    ...     ...
# Rodney Hood         Utah Jazz     5.0       SG  23.0    6-8   206.0
# Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# Jae Crowder        Marquette  6796117.0
# ...

# %%
#iteration using rows
for i,j in data.iterrows():
    print(i,j)
    print()
# Out:
# Avery Bradley Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
# Jae Crowder Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: Jae Crowder, dtype: object
#
# John Holland Team           Boston Celtics
# Number                   30.0
# Position                   SG
# Age                      27.0
# Height                    6-5
# Weight                  205.0
# College     Boston University
# Salary                    NaN
# Name: John Holland, dtype: object
#
# R.J. Hunter Team        Boston Celtics
# Number                28.0
# Position                SG
# ...

# %%
#iteration of columns
columns=data.columns
print(columns)
for i in columns:
    print(data[i][2])
# Out:
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'],
#       dtype='object')
# Boston Celtics
# 30.0
# SG
# 27.0
# 6-5
# 205.0
# Boston University
# nan

# %%
#series
data = pd.Series([5, 2, 3,7], index=['a', 'b', 'c', 'd'])
 
# creating a series
data1 = pd.Series([1, 6, 4, 9], index=['a', 'b', 'c', 'd'])
 
print(data)
print()
print(data1)
# Out:
# a    5
# b    2
# c    3
# d    7
# dtype: int64
#
# a    1
# b    6
# c    4
# d    9
# dtype: int64

# %%
# adding values of 2 series wrt indices
data.add(data1,fill_value=0)
# Out:
# a     6
# b     8
# c     7
# d    16
# dtype: int64

# %%
#subtracting of 2 series wrt indices
data.sub(data1,fill_value=0)
# Out:
# a    4
# b   -4
# c   -1
# d   -2
# dtype: int64

# %%
#returning top n rows
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
#print(data.head())
#print(data.iloc[[4,6,8,10]])
print(data[4:12:2])
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
#
#        College     Salary
# 4          NaN  5000000.0
# 6          LSU  1170960.0
# 8   Louisville  1824360.0
# 10  Ohio State  2569260.0

# %%
#on series
series = data["Name"]
top = series.head(10)
print(top)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %%
#describe method gives the statistical details
perc =[.20, .40, .60, .80]
print(data.describe(percentiles=perc))
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 20%      4.000000   23.000000  195.600000  9.472760e+05
# 40%     10.000000   25.000000  213.400000  1.938840e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 60%     18.600000   27.000000  230.000000  3.815000e+06
# 80%     30.000000   30.000000  245.000000  8.042895e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
#column selection
print(data[['Number',"Age"]])
# Out:
#      Number   Age
# 0       0.0  25.0
# 1      99.0  25.0
# 2      30.0  27.0
# 3      28.0  22.0
# 4       8.0  29.0
# ..      ...   ...
# 453     8.0  26.0
# 454    25.0  24.0
# 455    21.0  26.0
# 456    24.0  26.0
# 457     NaN   NaN
#
# [458 rows x 2 columns]

# %%
#column addition
height=pd.Series(data['Age'])
data["height"]=height #added height column
#print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  height
# 0                Texas  7730337.0    25.0
# ...

# %%
#column deletion 
data.drop(["height"],axis=1,inplace=True) #removed height column
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#Row Addition
new_row = pd.DataFrame({'Name':'varma', 'Team':'Ipl', 'Number':3,
                        'Position':'PG', 'Age':33, 'Height':'6-2',
                        'Weight':189, 'College':'SRKR', 'Salary':99999},index=[1])
data=pd.concat((new_row,data),ignore_index=True)
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0            varma             Ipl     3.0       PG  33.0    6-2   189.0
# 1    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 454   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 456   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 458            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                 SRKR    99999.0
# ...

# %%
#deleting row values
data.drop(index=1,axis=0,inplace=True)
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0            varma             Ipl     3.0       PG  33.0    6-2   189.0
# 2      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 5    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 454   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 456   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 458            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                 SRKR    99999.0
# ...

# %%
#selecting all rows with some columns using loc method
rows = data.loc[:, ["Team", "Number", "Position"]]
print(rows)
# Out:
#                Team  Number Position
# 0               Ipl     3.0       PG
# 2    Boston Celtics    99.0       SF
# 3    Boston Celtics    30.0       SG
# 4    Boston Celtics    28.0       SG
# 5    Boston Celtics     8.0       PF
# ..              ...     ...      ...
# 454       Utah Jazz     8.0       PG
# 455       Utah Jazz    25.0       PG
# 456       Utah Jazz    21.0        C
# 457       Utah Jazz    24.0        C
# 458             NaN     NaN      NaN
#
# [458 rows x 3 columns]

# %%
#selecting all rows and some columns usign iloc method
row2 = data.iloc [:, [0, 2]]
print(row2)
# Out:
#               Name  Number
# 0            varma     3.0
# 2      Jae Crowder    99.0
# 3     John Holland    30.0
# 4      R.J. Hunter    28.0
# 5    Jonas Jerebko     8.0
# ..             ...     ...
# 454   Shelvin Mack     8.0
# 455      Raul Neto    25.0
# 456   Tibor Pleiss    21.0
# 457    Jeff Withey    24.0
# 458            NaN     NaN
#
# [458 rows x 2 columns]

# %%
# masking data based on column values
print(data['Age'] > 25)
# Out:
# 0       True
# 2      False
# 3       True
# 4      False
# 5       True
#        ...
# 454     True
# 455    False
# 456     True
# 457     True
# 458    False
# Name: Age, Length: 458, dtype: bool

# %%
# masking data based on index value
mask = data.index > 7
data[mask]
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 8       Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 9       Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 10      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 11   Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 12     Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 454     Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455        Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 456     Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457      Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 458              NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#             College     Salary
# 8           Gonzaga  2165160.0
# ...

# %%
#using groupby
data1 ={'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA'],
        'Score': [23, 34, 35, 45, 47, 50, 52, 53]}
df = pd.DataFrame(data1)
print(df)
print(df.groupby('Address').groups) #groupby is done on address
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 4  Gaurav   33    Jaunpur        B.Tech     47
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52
# 7    Abhi   32    Aligarh            MA     53
# {'Aligarh': [7], 'Allahabad': [2, 6], 'Jaunpur': [4], 'Kannuaj': [3], 'Kanpur': [1, 5], 'Nagpur': [0]}

# %%
#grouping data by sorting keys , as it increases computation speed
print(df.groupby('Name').sum()) #without using sort parameter
print(df.groupby('Name',sort=False).sum()) #with using sort parameter
# Out:
#         Age  Score
# Name
# Abhi     32     53
# Anuj     60     84
# Gaurav   33     47
# Jai      49     58
# Princi   59     97
#         Age  Score
# Name
# Jai      49     58
# Anuj     60     84
# Princi   59     97
# Gaurav   33     47
# Abhi     32     53

# %%
#iteration
grp=df.groupby('Name')
for name,group in grp:
    print(name)
    print(group)
# Out:
# Abhi
#    Name  Age  Address Qualification  Score
# 7  Abhi   32  Aligarh            MA     53
# Anuj
#    Name  Age Address Qualification  Score
# 1  Anuj   24  Kanpur            MA     34
# 5  Anuj   36  Kanpur         B.com     50
# Gaurav
#      Name  Age  Address Qualification  Score
# 4  Gaurav   33  Jaunpur        B.Tech     47
# Jai
#   Name  Age    Address Qualification  Score
# 0  Jai   27     Nagpur           Msc     23
# 2  Jai   22  Allahabad           MCA     35
# Princi
#      Name  Age    Address Qualification  Score
# 3  Princi   32    Kannuaj           Phd     45
# 6  Princi   27  Allahabad           Msc     52

# %%
#selecting a particular group
grp = df.groupby(['Name', 'Qualification'])
print(grp.get_group(('Jai', 'Msc')))
# Out:
#   Name  Age Address Qualification  Score
# 0  Jai   27  Nagpur           Msc     23

# %%
#performing aggregations on particular column
grp=df.groupby('Name')
print(grp['Age'].aggregate([np.sum,np.mean,np.std]))
print(grp)
# Out:
#         sum  mean       std
# Name
# Abhi     32  32.0       NaN
# Anuj     60  30.0  8.485281
# Gaurav   33  33.0       NaN
# Jai      49  24.5  3.535534
# Princi   59  29.5  3.535534
# ...

# %%
#performing different aggregation on diff columns
print(grp.agg({'Age' : 'sum', 'Score' : 'std'}))
# Out:
#         Age      Score
# Name
# Abhi     32        NaN
# Anuj     60  11.313708
# Gaurav   33        NaN
# Jai      49   8.485281
# Princi   59   4.949747

# %%
#performing transformations
grp = df.groupby('Name')
sc = lambda x: (x - x.mean()) / x.std()*10
grp[["Age","Score"]].transform(sc)
# Out:
#         Age     Score
# 0  7.071068 -7.071068
# 1 -7.071068 -7.071068
# 2 -7.071068  7.071068
# 3  7.071068 -7.071068
# 4       NaN       NaN
# 5  7.071068  7.071068
# 6 -7.071068  7.071068
# 7       NaN       NaN

# %%
#filtration technique
grp = df.groupby('Name')
print(grp.filter(lambda x: len(x) >= 2))
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52

# %%
#concatenating dataframes by setting logic on axes
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 
data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]} 
  
df = pd.DataFrame(data1,index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 
 
print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000

# %%
#concatenating dataframes by setting logic on axes
new_df = pd.concat([df, df1], axis=1, join='inner') #inner join only common indexes
print(new_df)
# Out:
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2  Gaurav   22  Allahabad           MCA         58  Gaurav   22  Allahabad
# 3    Anuj   32    Kannuaj           Phd         76    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
#concatenating dataframe by ignoring index
print(df,"\n\n",df1)
res = pd.concat([df, df1], ignore_index=True)
res
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# ...

# %%
#concatenating dataframe and series
s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 

df = pd.DataFrame(data1)
print(df,"\n\n",s1)
print()
print(pd.concat(([df,s1]),axis=1))
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: Salary, dtype: int64
#
#      Name  Age    Address Qualification  Salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannuaj           Phd    4000

# %%
# Merging a dataframe with one unique key combination
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
   
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}  
df = pd.DataFrame(data1)

df1 = pd.DataFrame(data2) 

print(df, "\n\n", df1)
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#
#    key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons

# %%
merged_df = pd.merge(df, df1, on='key')
print(merged_df)
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
#Merging dataframe using how in an argument

data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
   
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
 
df = pd.DataFrame(data1)
 
df1 = pd.DataFrame(data2) 
  
print(df, "\n\n", df1)
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons

# %%
merged_df = pd.merge(df, df1, how='left', on=['key', 'key1']) #left merging
print(merged_df)
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN

# %%
merged_df = pd.merge(df, df1, how='outer', on=['key', 'key1']) #union of keys   
merged_df
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K1  Princi  24.0        NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K1    Anuj  32.0        NaN           NaN
# 4  K1   K0     NaN   NaN     Kanpur           B.A
# 5  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
#joining dataframes
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32]} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
  
df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])
  
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])
 
 
print(df, "\n\n", df1)
# Out:
#       Name  Age
# K0     Jai   27
# K1  Princi   24
# K2  Gaurav   22
# K3    Anuj   32
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons

# %%
joined_df = df.join(df1, how='outer')
print(joined_df)
# Out:
#       Name   Age    Address Qualification
# K0     Jai  27.0  Allahabad           MCA
# K1  Princi  24.0        NaN           NaN
# K2  Gaurav  22.0    Kannuaj           Phd
# K3    Anuj  32.0  Allahabad          Bcom
# K4     NaN   NaN    Kannuaj        B.hons

# %%
#Joining dataframe using on in an argument :
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],
        'Key':['K0', 'K1', 'K2', 'K3']} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1) 
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])
print(df, "\n\n", df1)
# Out:
#      Name  Age Key
# 0     Jai   27  K0
# 1  Princi   24  K1
# 2  Gaurav   22  K2
# 3    Anuj   32  K3
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons

# %%
joined_df = df.join(df1, on='Key')
print(joined_df)
# Out:
#      Name  Age Key    Address Qualification
# 0     Jai   27  K0  Allahabad           MCA
# 1  Princi   24  K1        NaN           NaN
# 2  Gaurav   22  K2    Kannuaj           Phd
# 3    Anuj   32  K3  Allahabad          Bcom

# %%
#Hands on date-time series
data = pd.date_range('03/22/2022', periods = 10, freq ='H')
data
# Out:
# DatetimeIndex(['2022-03-22 00:00:00', '2022-03-22 01:00:00',
#                '2022-03-22 02:00:00', '2022-03-22 03:00:00',
#                '2022-03-22 04:00:00', '2022-03-22 05:00:00',
#                '2022-03-22 06:00:00', '2022-03-22 07:00:00',
#                '2022-03-22 08:00:00', '2022-03-22 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
t = pd.Timestamp.now()
# Convert timestamp to datetime
t=pd.to_datetime(t)
print(t)
print(t.day)
print(t.month)
print(t.week)
print(t.hour)
print(t.minute)
# Out:
# 2022-03-23 10:32:00.109406
# 23
# 3
# 12
# 10
# 32

# %%
# realtime problem
df=pd.read_csv('http://bit.ly/uforeports')
print(df)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df['Time'] = pd.to_datetime(df.Time) #converting into datetime format
print(df.head())
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df["Time"].dt.hour.head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
df.Time.dt.day_name().head()
# Out:
# 0     Sunday
# 1     Monday
# 2     Sunday
# 3     Monday
# 4    Tuesday
# Name: Time, dtype: object

# %%
#String methods
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
print(data.head(10))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
#converting college feature into upper case
data['College']=data['College'].str.upper()
print(data['College'])
# Out:
# 0                  TEXAS
# 1              MARQUETTE
# 2      BOSTON UNIVERSITY
# 3          GEORGIA STATE
# 4                    NaN
#              ...
# 453               BUTLER
# 454                  NaN
# 455                  NaN
# 456               KANSAS
# 457                  NaN
# Name: College, Length: 458, dtype: object

# %%
#splitting columns 
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                TEXAS  7730337.0
# ...

# %%
#splitting values
print(data["College"].str.split("A",n=1, expand = True))
# Out:
#                      0        1
# 0                  TEX        S
# 1                    M  RQUETTE
# 2    BOSTON UNIVERSITY     None
# 3               GEORGI    STATE
# 4                  NaN      NaN
# ..                 ...      ...
# 453             BUTLER     None
# 454                NaN      NaN
# 455                NaN      NaN
# 456                  K     NSAS
# 457                NaN      NaN
#
# [458 rows x 2 columns]

# %%
#replace
print(data["Age"].replace(25.0, "Twenty five"))
# Out:
# 0      Twenty five
# 1      Twenty five
# 2             27.0
# 3             22.0
# 4             29.0
#           ...
# 453           26.0
# 454           24.0
# 455           26.0
# 456           26.0
# 457            NaN
# Name: Age, Length: 458, dtype: object

# %%
#concatenation of data
new = data["Team"].copy()
data["Name"]= data["Name"].str.cat(new, sep =", ")
print(data.Name)
# Out:
# 0      Avery Bradley, Boston Celtics
# 1        Jae Crowder, Boston Celtics
# 2       John Holland, Boston Celtics
# 3        R.J. Hunter, Boston Celtics
# 4      Jonas Jerebko, Boston Celtics
#                    ...
# 453          Shelvin Mack, Utah Jazz
# 454             Raul Neto, Utah Jazz
# 455          Tibor Pleiss, Utah Jazz
# 456           Jeff Withey, Utah Jazz
# 457                              NaN
# Name: Name, Length: 458, dtype: object

# %%
s = pd.Series(['a1', 'b2', 'c3'])
 
# Extracting a data
n = s.str.extract(r'(?P<first>[ab])(?P<second>\d)')
 
print(n)
# Out:
#   first second
# 0     a      1
# 1     b      2
# 2   NaN    NaN

# %%
data=pd.read_csv("/home/neosoft/Downloads/nba.csv",usecols =["Name"],skiprows = [1, 2, 3, 4])
data
# Out:
#               Name
# 0    Jonas Jerebko
# 1     Amir Johnson
# 2    Jordan Mickey
# 3     Kelly Olynyk
# 4     Terry Rozier
# ..             ...
# 449   Shelvin Mack
# 450      Raul Neto
# 451   Tibor Pleiss
# 452    Jeff Withey
# 453            NaN
#
# [454 rows x 1 columns]
